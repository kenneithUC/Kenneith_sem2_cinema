# %% [markdown]
# # ISB02303302 – Statistics for Business
# ## Classroom Exercise Week 4: Numerical Measures

# %% [markdown]
# ### Import libraries

# %%
import statistics as stat

import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st

# %% [markdown]
# ### Population Mean
# ![image.png](data:image/png;base64,...)

# %%
# Enter the formula to calculate population mean and calculate the population mean of patents granted.

X = ___
N = ___

Mu = ___
# Out:
# Arithmetic Mean for 12 Patents Granted is 195.00

# %% [markdown]
# ### Mean, Median, Modus

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Make a list called house_price_data

house_price_data = [___, ___, ___, ___]
print(house_price_data)

# Calculate the mean, median, mode, and standard deviation of house prices
# Utilize the following libraries: numpy, statistics, atau scipy.stats
# Out:
# [2000000, 500000, 300000, 100000, 100000]
# Mean:  600000
# Median:  300000
# Modus:  100000
# Standard Deviation: 800000.00

# %%
# Buatlah visualisasi harga rumah dengan bar chart

plt.bar(range(len(house_price_data)), house_price_data, color="orange")
plt.title("House Price Data", pad=20)
plt.xlabel("House")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ### Weighted Mean

# %% [markdown]
# A construction company has a wage plan of 16.50, 19.00, or 26.00 per hour. In total there are 26 workers, 14 people are paid wages of 16.50, 10 people are paid wages of 19.00, and 2 people are paid wages of 26.00. What is the average worker's wage?

# %%
# Make a couple of variabel named worker_wages and worker_number 
worker_wages = [___, ___, ___]
worker_number = [___, ___, ___]

# Calculate the average worker's wage
# Out:
# The average worker's wage is : 18.19

# %% [markdown]
# ### Geometric Mean

# %% [markdown]
# Let's say you receive a 5 percent raise this year and a 15 percent raise next year. What is the average salary increase?

# %%
# Make a list variable named salary_increase

salary_increase = [___, ___]

# Use the scipy.stats or statistics library to calculate the geometric mean, displaying up to 4 decimal places
# Out:
# The average salary increase is : 9.8863%
# The average salary increase is : 9.8863%

# %% [markdown]
# The return on investment earned by Atkins
# construction Company for four successive years was:
# 30 percent, 20 percent, - 40 percent, and 200
# percent. What is the geometric mean rate of return
# on investment?

# %%
# Make a list named roi_data

roi_data = [___, ___, ___, ___]

# Use the scipy.stats or statistics library to calculate the geometric mean, displaying up to 4 decimal places
# Out:
# The average ROI is : 29.4492%
# The average ROI is : 29.4492%

# %% [markdown]
# During the 1990s, and into the 2000s, Las Vegas, Nevada, was the fastest growing city in the US. The population increased from 258,295 in 1990 to 607,876 in 2009. This is an increase of 349,581 people or an increase of 135.3% over that period. The population more than doubled. What is the average annual increase?
# ![image.png](data:image/png;base64,...)

# %%
# Use the average annual increase formula
value_at_end_period = ___
value_at_start_period = ___
rate_of_increase_over_time = ___
print("The average annual increase is : {0:.8f}".format(rate_of_increase_over_time))
# Out:
# The average annual increase is : 0.04607568

# %% [markdown]
# ## Additional Exercise (Optional)
#
# Calculate the mean, median, mode, range and standard deviation for the physical attacks of fighter type heroes
#
# Use the following MLBB dataset: https://raw.githubusercontent.com/twiradinata/datasets/main/mlbb_hero.csv

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/twiradinata/datasets/main/mlbb_hero.csv'
df = pd.read_csv(url, delimiter=';')
df.head()
# Out:
#   hero_name      role  defense_overall  offense_overall  skill_effect_overall  \
# 0   Terizla   fighter              7.0              8.0                   6.0
# 1    Martis   fighter              6.0              8.0                   5.0
# 2     Grock      tank              8.0              5.0                   6.0
# 3  Carmilla   support              5.0              5.0                   9.0
# 4   Irithel  marksman              5.0              5.0                   8.0
#
#    difficulty_overall  movement_spd  magic_defense  mana  hp_regen  \
# 0                 6.0           255             10   430        54
# 1                 5.0           260             10     0        35
# 2                 4.0           260             10   430        42
# 3                 5.0           255             10   430        39
# 4                 7.0           260             10   438        35
#
#    physical_atk  physical_defense    hp  attack_speed  mana_regen  win_rate  \
# ...

# %%
# Out:
# Mean for Fighter 119.9655
# Median for Fighter 121
# Mode for Fighter [121, 119]
# Range for Fighter 28
# Standar Deviation for Fighter 7.0735

# %% [markdown]
# ## End of Exercise
